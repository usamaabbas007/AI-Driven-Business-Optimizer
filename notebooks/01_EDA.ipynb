# %% [markdown]
# # Exploratory Data Analysis
# This notebook explores trends in historical sales and inventory data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load sample dataset
df = pd.read_csv('../data/raw/sample_sales.csv')
df.head()
