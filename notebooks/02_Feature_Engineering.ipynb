# %% [markdown]
# # Feature Engineering
# We generate time-based and aggregated features for model training.

# %%
df['date'] = pd.to_datetime(df['date'])
df['day_of_week'] = df['date'].dt.dayofweek
df['month'] = df['date'].dt.month
